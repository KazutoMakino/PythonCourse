# %% [markdown]
# # pandas で concat する速度の比較

# %% [markdown]
# 1. 行数が 1_000_000 くらいのテーブルを作成する
# 2. 1.で作成したテーブルを for 文使って行方向に 20 個結合する時間について，以下のケースで 100 回ずつ測定
#    - list[pd.DataFrame] を作り pd.concat する
#    - pd.DataFrame に毎回 pd.concat する
# 3. 2.を polars についても同様に試す

# %% [markdown]
# ---

# %% [markdown]
# ## import

# %%
import gc
import sys
from time import perf_counter

import numpy as np
import pandas as pd
import polars as pl
from tqdm import tqdm

# %%
sys.version
# Out:
# '3.11.4 (main, Jul 12 2023, 00:30:27) [GCC 11.3.0]'

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
pl.__version__
# Out:
# '0.19.5'

# %% [markdown]
# ## fn

# %%
def get_process_time_intervals(
    concat_mode: str = "many_times",
    lib_name: str = "pandas",
    num_try: int = 100,
    num_concat: int = 20,
    data_range: int = 1_000_000,
) -> list[float]:
    assert concat_mode in ["many_times", "only_once"], ValueError(
        f"concat_mode={concat_mode} は 'many_times' もしくは 'only_once' のみ使用可能です"
    )
    assert lib_name in ["pandas", "polars"], ValueError(
        f"lib_name={lib_name} は 'pandas' もしくは 'polars' のみ使用可能です"
    )

    x = np.arange(0, data_range, 1, dtype=np.float64)
    if lib_name == "pandas":
        df_tmp = pd.DataFrame(
            data={"col_0": x, "col_1": x, "col_2": x, "col_3": x, "col_4": x}
        )
    elif lib_name == "polars":
        df_tmp = pl.DataFrame(
            data={"col_0": x, "col_1": x, "col_2": x, "col_3": x, "col_4": x}
        )

    list_time: list[float] = []
    for _ in tqdm(range(num_try)):
        t_start = perf_counter()

        if concat_mode == "many_times":
            if lib_name == "pandas":
                df = pd.DataFrame()
                for _ in range(num_concat):
                    df = pd.concat(objs=[df, df_tmp], axis=0)
                # df.reset_index(drop=True, inplace=True)

            elif lib_name == "polars":
                df = pl.DataFrame()
                for _ in range(num_concat):
                    df = pl.concat(items=[df, df_tmp], how="vertical")

        elif concat_mode == "only_once":
            list_dfs: list = []
            for _ in range(num_concat):
                list_dfs.append(df_tmp)

            if lib_name == "pandas":
                df = pd.concat(objs=list_dfs, axis=0)
                # df.reset_index(drop=True, inplace=True)

            elif lib_name == "polars":
                df = pl.concat(items=list_dfs, how="vertical")

        t_elapsed = perf_counter() - t_start
        assert df.__len__() == num_concat * data_range, ValueError
        list_time.append(t_elapsed)

    del df
    gc.collect()

    return list_time

# %%
df_time = pd.DataFrame(
    data={
        "pandas_concat_list_dfs_only_once": get_process_time_intervals(
            concat_mode="only_once", lib_name="pandas"
        ),
        "pandas_concat_df_many_times": get_process_time_intervals(
            concat_mode="many_times", lib_name="pandas"
        ),
        "polars_concat_list_dfs_only_once": get_process_time_intervals(
            concat_mode="only_once", lib_name="polars"
        ),
        "polars_concat_df_many_times": get_process_time_intervals(
            concat_mode="many_times", lib_name="polars"
        ),
    }
)
df_time
# Out:
# 100%|██████████| 100/100 [00:23<00:00,  4.21it/s]
# 100%|██████████| 100/100 [04:23<00:00,  2.63s/it]
# 100%|██████████| 100/100 [00:17<00:00,  5.63it/s]
# 100%|██████████| 100/100 [03:18<00:00,  1.99s/it]
#     pandas_concat_list_dfs_only_once  pandas_concat_df_many_times  \
# 0                           0.577719                     2.408093
# 1                           0.481048                     3.251420
# 2                           0.230936                     2.797252
# 3                           0.274883                     2.510188
# 4                           0.262519                     2.890913
# ..                               ...                          ...
# 95                          0.178446                     2.647607
# 96                          0.184727                     2.141587
# 97                          0.181073                     2.114850
# 98                          0.185886                     2.061302
# 99                          0.198160                     2.176131
#
#     polars_concat_list_dfs_only_once  polars_concat_df_many_times
# 0                           0.166258                     1.950960
# 1                           0.170176                     2.380181
# 2                           0.176868                     2.278071
# 3                           0.165578                     2.302411
# 4                           0.172486                     2.342867
# ..                               ...                          ...
# 95                          0.149601                     2.036742
# 96                          0.139801                     2.038443
# 97                          0.146241                     1.946197
# 98                          0.166531                     1.908553
# 99                          0.158464                     2.024409
#
# [100 rows x 4 columns]

# %%
df_desc = df_time.describe().T
df_desc.drop(columns=["count"], inplace=True)
df_desc["median"] = df_time.median()
df_desc.sort_values(by="median", inplace=True)

df_desc.style.bar(color="blue", align="zero")
# Out:
# <style type="text/css">
# #T_6a1cc_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.3%, transparent 53.3%);
# }
# #T_6a1cc_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.9%, transparent 57.9%);
# }
# #T_6a1cc_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.6%, transparent 53.6%);
# }
# #T_6a1cc_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
# }
# #T_6a1cc_row0_col4, #T_6a1cc_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.0%, transparent 53.0%);
# }
# #T_6a1cc_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.8%, transparent 52.8%);
# }
# #T_6a1cc_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.0%, transparent 58.0%);
# }
# #T_6a1cc_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.5%, transparent 54.5%);
# }
# #T_6a1cc_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.0%, transparent 59.0%);
# }
# #T_6a1cc_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.4%, transparent 54.4%);
# }
# #T_6a1cc_row1_col3, #T_6a1cc_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.1%, transparent 54.1%);
# }
# #T_6a1cc_row1_col4, #T_6a1cc_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.9%, transparent 53.9%);
# }
# #T_6a1cc_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.0%, transparent 57.0%);
# }
# #T_6a1cc_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 87.8%, transparent 87.8%);
# }
# #T_6a1cc_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.2%, transparent 65.2%);
# }
# #T_6a1cc_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 97.9%, transparent 97.9%);
# }
# #T_6a1cc_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 92.9%, transparent 92.9%);
# }
# #T_6a1cc_row2_col4, #T_6a1cc_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 88.9%, transparent 88.9%);
# }
# #T_6a1cc_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 85.5%, transparent 85.5%);
# }
# #T_6a1cc_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 82.7%, transparent 82.7%);
# }
# #T_6a1cc_row3_col0, #T_6a1cc_row3_col1, #T_6a1cc_row3_col2, #T_6a1cc_row3_col3, #T_6a1cc_row3_col4, #T_6a1cc_row3_col5, #T_6a1cc_row3_col6, #T_6a1cc_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_6a1cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a1cc_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_6a1cc_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_6a1cc_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_6a1cc_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_6a1cc_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_6a1cc_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_6a1cc_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_6a1cc_level0_col7" class="col_heading level0 col7" >median</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a1cc_level0_row0" class="row_heading level0 row0" >polars_concat_list_dfs_only_once</th>
#       <td id="T_6a1cc_row0_col0" class="data row0 col0" >0.176083</td>
#       <td id="T_6a1cc_row0_col1" class="data row0 col1" >0.087882</td>
#       <td id="T_6a1cc_row0_col2" class="data row0 col2" >0.131148</td>
#       <td id="T_6a1cc_row0_col3" class="data row0 col3" >0.142313</td>
#       <td id="T_6a1cc_row0_col4" class="data row0 col4" >0.153726</td>
#       <td id="T_6a1cc_row0_col5" class="data row0 col5" >0.163281</td>
#       <td id="T_6a1cc_row0_col6" class="data row0 col6" >0.706469</td>
#       <td id="T_6a1cc_row0_col7" class="data row0 col7" >0.153726</td>
#     </tr>
#     <tr>
#       <th id="T_6a1cc_level0_row1" class="row_heading level0 row1" >pandas_concat_list_dfs_only_once</th>
#       <td id="T_6a1cc_row1_col0" class="data row1 col0" >0.235592</td>
#       <td id="T_6a1cc_row1_col1" class="data row1 col1" >0.100332</td>
#       <td id="T_6a1cc_row1_col2" class="data row1 col2" >0.160950</td>
#       <td id="T_6a1cc_row1_col3" class="data row1 col3" >0.181542</td>
#       <td id="T_6a1cc_row1_col4" class="data row1 col4" >0.195120</td>
#       <td id="T_6a1cc_row1_col5" class="data row1 col5" >0.235982</td>
#       <td id="T_6a1cc_row1_col6" class="data row1 col6" >0.620031</td>
#       <td id="T_6a1cc_row1_col7" class="data row1 col7" >0.195120</td>
#     </tr>
#     <tr>
#       <th id="T_6a1cc_level0_row2" class="row_heading level0 row2" >polars_concat_df_many_times</th>
#       <td id="T_6a1cc_row2_col0" class="data row2 col0" >1.988170</td>
#       <td id="T_6a1cc_row2_col1" class="data row2 col1" >0.169783</td>
#       <td id="T_6a1cc_row2_col2" class="data row2 col2" >1.736401</td>
#       <td id="T_6a1cc_row2_col3" class="data row2 col3" >1.881851</td>
#       <td id="T_6a1cc_row2_col4" class="data row2 col4" >1.963711</td>
#       <td id="T_6a1cc_row2_col5" class="data row2 col5" >2.038146</td>
#       <td id="T_6a1cc_row2_col6" class="data row2 col6" >2.908779</td>
#       <td id="T_6a1cc_row2_col7" class="data row2 col7" >1.963711</td>
#     </tr>
#     <tr>
#       <th id="T_6a1cc_level0_row3" class="row_heading level0 row3" >pandas_concat_df_many_times</th>
#       <td id="T_6a1cc_row3_col0" class="data row3 col0" >2.629965</td>
#       <td id="T_6a1cc_row3_col1" class="data row3 col1" >0.559238</td>
#       <td id="T_6a1cc_row3_col2" class="data row3 col2" >1.813775</td>
#       <td id="T_6a1cc_row3_col3" class="data row3 col3" >2.191198</td>
#       <td id="T_6a1cc_row3_col4" class="data row3 col4" >2.526360</td>
#       <td id="T_6a1cc_row3_col5" class="data row3 col5" >2.869135</td>
#       <td id="T_6a1cc_row3_col6" class="data row3 col6" >4.442604</td>
#       <td id="T_6a1cc_row3_col7" class="data row3 col7" >2.526360</td>
#     </tr>
#   </tbody>
# </table>
